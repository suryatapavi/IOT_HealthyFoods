# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("fg_directional_satements-en_ONPP.csv")
# Out:
#   fgid                              directional-statement
# 0   vf  Eat at least one dark green and one orange veg...
# 1   vf  Choose vegetables and fruit prepared with litt...
# 2   vf   Have vegetables and fruit more often than juice.
# 3   gr  Make at least half of your grain products whol...
# 4   gr  Choose grain products that are lower in fat, s...
# 5   mi               Drink skim, 1%, or 2% milk each day.
# 6   mi                Select lower fat milk alternatives.
# 7   me  Have meat alternatives such as beans, lentils ...
# 8   me  Eat at least two Food Guide Servings of fish e...
# 9   me  Select lean meat and alternatives prepared wit...

# %%
pd.read_csv("foodgroups-en_ONPP.csv")
# Out:
#   fgid              foodgroup  fgcat_id                               fgcat
# 0   vf   Vegetables and Fruit         0  Non dark green or orange vegetable
# 1   vf   Vegetables and Fruit         1                Dark green vegetable
# 2   vf   Vegetables and Fruit         2                    Orange vegetable
# 3   gr                 Grains         4                     Non whole grain
# 4   gr                 Grains         3                         Whole grain
# 5   mi  Milk and Alternatives         5                                Milk
# 6   mi  Milk and Alternatives         6                  Milk Alternataives
# 7   me  Meat and Alternatives         7                   Meat Alternatives
# 8   me  Meat and Alternatives         8   Meat, fish, poultry and shellfish

# %%
pd.read_csv("servings_per_day-en_ONPP.csv")
# Out:
#    fgid  gender      ages servings
# 0    vf  Female    2 to 3        4
# 1    vf    Male   2 to 3         4
# 2    vf  Female    4 to 8        5
# 3    vf    Male    4 to 8        5
# 4    vf  Female   9 to 13        6
# 5    vf    Male   9 to 13        6
# 6    vf  Female  14 to 18        7
# 7    vf    Male  14 to 18        8
# 8    vf  Female  19 to 30   7 to 8
# 9    vf    Male  19 to 30  8 to 10
# 10   vf  Female  31 to 50   7 to 8
# 11   vf    Male  31 to 50  8 to 10
# 12   vf  Female  51 to 70        7
# 13   vf    Male  51 to 70        7
# 14   vf  Female       71+        7
# 15   vf    Male       71+        7
# 16   gr  Female    2 to 3        3
# 17   gr    Male    2 to 3        3
# 18   gr  Female    4 to 8        4
# 19   gr    Male    4 to 8        4
# 20   gr  Female   9 to 13        6
# 21   gr    Male   9 to 13        6
# 22   gr  Female  14 to 18        6
# 23   gr    Male  14 to 18        7
# 24   gr  Female  19 to 30   6 to 7
# 25   gr    Male  19 to 30        8
# ...

# %%
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is A4AA-7FFF
#
#  Directory of D:\Automation\New folder\signal\data
#
# 2018-10-17  08:25 AM    <DIR>          .
# 2018-10-17  08:25 AM    <DIR>          ..
# 2018-10-17  08:25 AM               664 fg_directional_satements-en_ONPP.csv
# 2018-10-17  08:25 AM               429 foodgroups-en_ONPP.csv
# 2018-10-17  08:25 AM             6,471 foods-en_ONPP_rev.csv
# 2018-10-17  08:25 AM             1,354 servings_per_day-en_ONPP.csv
#                4 File(s)          8,918 bytes
#                2 Dir(s)  385,196,761,088 bytes free

# %%
pd.read_table("foods-en_ONPP_rev.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbd in position 14: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-17-cbbadf09b19f> in <module>()
# ----> 1 pd.read_table("foods-en_ONPP_rev.csv")
#
# ...
